# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="cost_per_win", y="wins", hue="superteam", alpha=0.7)
plt.title("Cost per Win vs Wins")
plt.xlabel("Cost per Win ($)")
plt.ylabel("Wins")
plt.xscale("log")  # Log scale helps show distribution
plt.legend(title="Superteam")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
avg_cost_season = df.groupby(["season", "superteam"])["cost_per_win"].mean().reset_index()
sns.lineplot(data=avg_cost_season, x="season", y="cost_per_win", hue="superteam", marker="o")
plt.title("Trend of Average Cost per Win Over Time")
plt.xlabel("Season")
plt.ylabel("Average Cost per Win ($)")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Copy and relabel team types
df_labeled = df.copy()
df_labeled["team_type"] = df_labeled["superteam"].map({"Yes": "Superteam", "No": "Balanced"})

# Boxplot: Cost per Win
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_labeled, x="team_type", y="cost_per_win")
plt.title("Cost per Win: Superteams vs Balanced Teams")
plt.xlabel("Team Type")
plt.ylabel("Cost per Win ($)")
plt.yscale("log")  # Log scale for better visibility of spread
plt.tight_layout()
plt.show()

# %%
# Group and average revenue per win by team type
avg_revenue_group = df_labeled.groupby("team_type")["revenue_per_win"].mean().reset_index()

# Bar chart with future-proof syntax
plt.figure(figsize=(8, 6))
sns.barplot(data=avg_revenue_group, x="team_type", y="revenue_per_win", hue="team_type", palette="Set2", legend=False)
plt.title("Average Revenue per Win: Superteams vs Balanced Teams")
plt.xlabel("Team Type")
plt.ylabel("Revenue per Win ($)")
plt.tight_layout()
plt.show()
